# %%
import pandas as pd

# %%
df=pd.DataFrame({'weight':[71, 89, 64, 74, 87,93, 79, 81, 75, 72, 70, 66, 81,78 , 110],'height':[51, 66, 45, 57, 64, 75, 61, 62, 55, 53, 48, 46, 63, 60, 100]})
df
# Out:
#     weight  height
# 0       71      51
# 1       89      66
# 2       64      45
# 3       74      57
# 4       87      64
# 5       93      75
# 6       79      61
# 7       81      62
# 8       75      55
# 9       72      53
# 10      70      48
# 11      66      46
# 12      81      63
# 13      78      60
# 14     110     100

# %%
import scipy

# %%
from scipy.stats import pearsonr

# %%
pearsonr(df.weight,df.height)
# Out:
# PearsonRResult(statistic=0.9812157743639651, pvalue=1.1309936956553374e-10)

# %%
from scipy.stats import spearmanr

# %%
spearmanr(df.weight,df.height)
# Out:
# SignificanceResult(statistic=0.9955321222799308, pvalue=1.033592510688058e-14)

# %%
from scipy import stats as st

# %%
x=(5, 7, 4, 9, 6, 7, 30, 40, 20, 10, )
st.ttest_1samp(x,20)
# Out:
# TtestResult(statistic=-1.5998853169908571, pvalue=0.1440882588016514, df=9)

# %%
import numpy as np
x=(5, 7, 4, 9, 6, 7, 30, 40, 20, 10, )
np.mean(x)
# Out:
# 13.8

# %%
x=(5, 7, 4, 9, 6, 7, 30, 40, 20, 10, )
st.ttest_1samp(x,13.7)
# Out:
# TtestResult(statistic=0.025804601886949677, pvalue=0.9799762964280812, df=9)

# %%
st.ttest_rel(df.weight, df.height)
# Out:
# TtestResult(statistic=23.796866865573996, pvalue=1.007250954859003e-12, df=14)

# %%
np.mean(df.weight)
# Out:
# 79.33333333333333

# %%
np.mean(df.height)
# Out:
# 60.4

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(20,5),columns=['January','February','March', 'April','May'])
df
# Out:
#      January  February     March     April       May
# 0   0.584626  0.378869  0.223315  0.011522  0.613122
# 1   0.352476  0.976986  0.255673  0.905740  0.461593
# 2   0.812867  0.430185  0.659282  0.856788  0.069895
# 3   0.807925  0.294100  0.739960  0.293202  0.602780
# 4   0.276312  0.980790  0.662311  0.870773  0.035858
# 5   0.936590  0.064615  0.445303  0.782008  0.540773
# 6   0.844857  0.712406  0.912493  0.226484  0.169319
# 7   0.341474  0.900266  0.867382  0.739689  0.614722
# 8   0.758963  0.625630  0.632360  0.725079  0.438656
# 9   0.980023  0.578434  0.624352  0.872001  0.787163
# 10  0.705814  0.858791  0.811456  0.496493  0.114518
# 11  0.460268  0.908471  0.671363  0.637041  0.991140
# 12  0.021018  0.110196  0.204489  0.406381  0.806733
# 13  0.201006  0.004476  0.363381  0.846243  0.058275
# 14  0.157692  0.815376  0.157822  0.228415  0.172765
# 15  0.354694  0.011057  0.167171  0.245179  0.445060
# 16  0.889159  0.372364  0.046257  0.003046  0.888415
# ...

# %%
df.plot.area(figsize=(10,10),title='sample')
# Out:
# <Axes: title={'center': 'sample'}>

# %%
df.plot.box(figsize=(10,10),title='sample')
# Out:
# <Axes: title={'center': 'sample'}>

# %%
import seaborn as sns

# %%
sns.set_style('darkgrid')
df.plot.box(figsize=(10,10),title='sample')
# Out:
# <Axes: title={'center': 'sample'}>

# %%
df.plot.density(figsize=(10,10),title='sample')
# Out:
# <Axes: title={'center': 'sample'}, ylabel='Density'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head().plot.pie(figsize=(30,30),subplots=True)
# Out:
# array([<Axes: ylabel='January'>, <Axes: ylabel='February'>,
#        <Axes: ylabel='March'>, <Axes: ylabel='April'>,
#        <Axes: ylabel='May'>], dtype=object)
